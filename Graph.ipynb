# %%
import networkx as nx
import matplotlib.pyplot as plt
import re

def parse_log_output(log_output):
    paths = []
    # Regex to find numeric sequences inside brackets
    path_regex = re.compile(r'path=\[(.*?)\]')
    for line in log_output.split('\n'):
        match = path_regex.search(line)
        if match:
            path_str = match.group(1)
            path = [int(node) for node in path_str.split(", ") if node.isdigit()]
            paths.append(path)
    return paths
# Your log output as a multiline string
log_output = """
Count=0, path=[41, 48]}
Starting search from node 47
AntMessage{source=47, content='28', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[47]}
AntMessage{source=47, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 44]}
AntMessage{source=47, content='28', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 46]}
AntMessage{source=47, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 11]}
AntMessage{source=47, content='28', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 7]}
Starting search from node 33
AntMessage{source=33, content='30', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[33]}
AntMessage{source=33, content='30', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[33, 42]}
AntMessage{source=33, content='30', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[33, 42, 8]}
AntMessage{source=33, content='30', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[33, 42, 26]}
AntMessage{source=33, content='30', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[33, 29]}
AntMessage{source=33, content='30', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[33, 29, 32]}
AntMessage{source=33, content='30', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[33, 29, 8]}
Starting search from node 18
AntMessage{source=18, content='45', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[18]}
Starting search from node 24
AntMessage{source=24, content='6', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[24]}
AntMessage{source=24, content='6', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[24, 10]}
AntMessage{source=24, content='6', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[24, 30]}
AntMessage{source=24, content='6', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[24, 30, 25]}
AntMessage{source=24, content='6', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[24, 30, 21]}
Starting search from node 37
AntMessage{source=37, content='7', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[37]}
AntMessage{source=37, content='7', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[37, 33]}
AntMessage{source=37, content='7', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[37, 33, 29]}
AntMessage{source=37, content='7', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[37, 33, 42]}
AntMessage{source=37, content='7', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[37, 4]}
Starting search from node 5
AntMessage{source=5, content='26', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[5]}
AntMessage{source=5, content='26', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[5, 22]}
AntMessage{source=5, content='26', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[5, 22, 40]}
AntMessage{source=5, content='26', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[5, 26]}
AntMessage{source=5, content='26', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[5, 22, 45]}
Starting search from node 27
AntMessage{source=27, content='30', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[27]}
AntMessage{source=27, content='30', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 0]}
AntMessage{source=27, content='30', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 48]}
AntMessage{source=27, content='30', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 26]}
AntMessage{source=27, content='30', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 18]}
Starting search from node 20
AntMessage{source=20, content='15', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[20]}
Starting search from node 26
AntMessage{source=26, content='8', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[26]}
Starting search from node 14
AntMessage{source=14, content='5', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[14]}
Starting search from node 18
AntMessage{source=18, content='31', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[18]}
Starting search from node 9
AntMessage{source=9, content='49', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[9]}
AntMessage{source=9, content='49', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[9, 16]}
AntMessage{source=9, content='49', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[9, 22]}
AntMessage{source=9, content='49', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[9, 22, 45]}
AntMessage{source=9, content='49', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[9, 22, 40]}
Starting search from node 34
AntMessage{source=34, content='46', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[34]}
AntMessage{source=34, content='46', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 6]}
AntMessage{source=34, content='46', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 1]}
Starting search from node 1
AntMessage{source=1, content='12', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[1]}
Starting search from node 5
AntMessage{source=5, content='0', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[5]}
AntMessage{source=5, content='0', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[5, 26]}
AntMessage{source=5, content='0', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[5, 22]}
AntMessage{source=5, content='0', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[5, 22, 40]}
AntMessage{source=5, content='0', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[5, 22, 45]}
Starting search from node 27
AntMessage{source=27, content='20', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[27]}
AntMessage{source=27, content='20', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 26]}
AntMessage{source=27, content='20', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 0]}
AntMessage{source=27, content='20', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 48]}
AntMessage{source=27, content='20', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 18]}
Starting search from node 23
AntMessage{source=23, content='35', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[23]}
AntMessage{source=23, content='35', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[23, 31]}
AntMessage{source=23, content='35', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[23, 49]}
AntMessage{source=23, content='35', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[23, 49, 35]}
AntMessage{source=23, content='35', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[23, 49, 45]}
Starting search from node 36
AntMessage{source=36, content='34', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[36]}
Starting search from node 25
AntMessage{source=25, content='24', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[25]}
AntMessage{source=25, content='24', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[25, 16]}
AntMessage{source=25, content='24', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[25, 37]}
AntMessage{source=25, content='24', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[25, 37, 33]}
AntMessage{source=25, content='24', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[25, 37, 4]}
Starting search from node 4
AntMessage{source=4, content='16', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[4]}
Starting search from node 4
AntMessage{source=4, content='33', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[4]}
Starting search from node 34
AntMessage{source=34, content='36', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[34]}
AntMessage{source=34, content='36', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 6]}
AntMessage{source=34, content='36', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 1]}
Starting search from node 31
AntMessage{source=31, content='23', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[31]}
Starting search from node 20
AntMessage{source=20, content='44', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[20]}
Starting search from node 16
AntMessage{source=16, content='1', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[16]}
Starting search from node 44
AntMessage{source=44, content='37', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[44]}
AntMessage{source=44, content='37', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[44, 7]}
AntMessage{source=44, content='37', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[44, 46]}
AntMessage{source=44, content='37', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[44, 7, 28]}
AntMessage{source=44, content='37', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[44, 7, 4]}
Starting search from node 13
AntMessage{source=13, content='33', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[13]}
AntMessage{source=13, content='33', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[13, 27]}
AntMessage{source=13, content='33', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[13, 49]}
AntMessage{source=13, content='33', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 49, 35]}
AntMessage{source=13, content='33', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 49, 45]}
AntMessage{source=13, content='33', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 27, 0]}
AntMessage{source=13, content='33', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 27, 26]}
Starting search from node 36
AntMessage{source=36, content='17', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[36]}
Starting search from node 46
AntMessage{source=46, content='34', pheromoneLevel=1.0, ttl=2, hitCount=1, path=[46]}
Starting search from node 25
AntMessage{source=25, content='41', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[25]}
AntMessage{source=25, content='41', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[25, 37]}
AntMessage{source=25, content='41', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[25, 37, 33]}
AntMessage{source=25, content='41', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[25, 16]}
AntMessage{source=25, content='41', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[25, 37, 4]}
Starting search from node 23
AntMessage{source=23, content='19', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[23]}
AntMessage{source=23, content='19', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[23, 49]}
AntMessage{source=23, content='19', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[23, 49, 35]}
AntMessage{source=23, content='19', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[23, 49, 45]}
AntMessage{source=23, content='19', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[23, 31]}
Starting search from node 15
AntMessage{source=15, content='45', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[15]}
AntMessage{source=15, content='45', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[15, 39]}
AntMessage{source=15, content='45', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[15, 40]}
Starting search from node 14
AntMessage{source=14, content='48', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[14]}
Starting search from node 20
AntMessage{source=20, content='20', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[20]}
Starting search from node 42
AntMessage{source=42, content='30', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[42]}
AntMessage{source=42, content='30', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[42, 26]}
AntMessage{source=42, content='30', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[42, 8]}
Starting search from node 48
AntMessage{source=48, content='13', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[48]}
Starting search from node 24
AntMessage{source=24, content='36', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[24]}
AntMessage{source=24, content='36', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[24, 10]}
AntMessage{source=24, content='36', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[24, 30]}
AntMessage{source=24, content='36', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[24, 30, 25]}
AntMessage{source=24, content='36', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[24, 30, 21]}
Starting search from node 36
AntMessage{source=36, content='46', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[36]}
Starting search from node 35
AntMessage{source=35, content='10', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[35]}
Starting search from node 29
AntMessage{source=29, content='5', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[29]}
AntMessage{source=29, content='5', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[29, 32]}
AntMessage{source=29, content='5', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[29, 32, 2]}
AntMessage{source=29, content='5', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[29, 8]}
AntMessage{source=29, content='5', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[29, 32, 36]}
Starting search from node 36
AntMessage{source=36, content='31', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[36]}
Starting search from node 45
AntMessage{source=45, content='18', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[45]}
AntMessage{source=45, content='18', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[45, 27]}
AntMessage{source=45, content='18', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[45, 27, 26]}
AntMessage{source=45, content='18', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[45, 43]}
AntMessage{source=45, content='18', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[45, 43, 36]}
AntMessage{source=45, content='18', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[45, 43, 6]}
AntMessage{source=45, content='18', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[45, 27, 0]}
Starting search from node 1
AntMessage{source=1, content='13', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[1]}
Starting search from node 48
AntMessage{source=48, content='33', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[48]}
Starting search from node 49
AntMessage{source=49, content='35', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[49]}
AntMessage{source=49, content='35', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[49, 35]}
AntMessage{source=49, content='35', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[49, 45]}
AntMessage{source=49, content='35', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[49, 45, 43]}
AntMessage{source=49, content='35', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[49, 45, 27]}
Starting search from node 40
AntMessage{source=40, content='26', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[40]}
Starting search from node 9
AntMessage{source=9, content='19', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[9]}
AntMessage{source=9, content='19', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[9, 16]}
AntMessage{source=9, content='19', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[9, 22]}
AntMessage{source=9, content='19', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[9, 22, 45]}
AntMessage{source=9, content='19', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[9, 22, 40]}
Starting search from node 42
AntMessage{source=42, content='36', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[42]}
AntMessage{source=42, content='36', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[42, 26]}
AntMessage{source=42, content='36', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[42, 8]}
Starting search from node 34
AntMessage{source=34, content='5', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[34]}
AntMessage{source=34, content='5', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 6]}
AntMessage{source=34, content='5', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 1]}
Starting search from node 18
AntMessage{source=18, content='31', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[18]}
Starting search from node 45
AntMessage{source=45, content='49', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[45]}
AntMessage{source=45, content='49', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[45, 27]}
AntMessage{source=45, content='49', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[45, 27, 26]}
AntMessage{source=45, content='49', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[45, 43]}
AntMessage{source=45, content='49', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[45, 43, 36]}
AntMessage{source=45, content='49', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[45, 43, 6]}
AntMessage{source=45, content='49', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[45, 27, 0]}
Starting search from node 49
AntMessage{source=49, content='37', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[49]}
AntMessage{source=49, content='37', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[49, 45]}
AntMessage{source=49, content='37', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[49, 45, 43]}
AntMessage{source=49, content='37', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[49, 45, 27]}
AntMessage{source=49, content='37', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[49, 35]}
Starting search from node 25
AntMessage{source=25, content='20', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[25]}
AntMessage{source=25, content='20', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[25, 37]}
AntMessage{source=25, content='20', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[25, 37, 4]}
AntMessage{source=25, content='20', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[25, 16]}
AntMessage{source=25, content='20', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[25, 37, 33]}
Starting search from node 37
AntMessage{source=37, content='40', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[37]}
AntMessage{source=37, content='40', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[37, 4]}
AntMessage{source=37, content='40', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[37, 33]}
AntMessage{source=37, content='40', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[37, 33, 42]}
AntMessage{source=37, content='40', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[37, 33, 29]}
Starting search from node 23
AntMessage{source=23, content='38', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[23]}
AntMessage{source=23, content='38', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[23, 31]}
AntMessage{source=23, content='38', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[23, 49]}
AntMessage{source=23, content='38', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[23, 49, 35]}
AntMessage{source=23, content='38', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[23, 49, 45]}
Starting search from node 7
AntMessage{source=7, content='13', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[7]}
AntMessage{source=7, content='13', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[7, 4]}
AntMessage{source=7, content='13', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[7, 28]}
Starting search from node 23
AntMessage{source=23, content='26', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[23]}
AntMessage{source=23, content='26', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[23, 31]}
AntMessage{source=23, content='26', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[23, 49]}
AntMessage{source=23, content='26', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[23, 49, 45]}
AntMessage{source=23, content='26', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[23, 49, 35]}
Starting search from node 22
AntMessage{source=22, content='3', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[22]}
AntMessage{source=22, content='3', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[22, 40]}
AntMessage{source=22, content='3', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[22, 45]}
AntMessage{source=22, content='3', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[22, 45, 27]}
AntMessage{source=22, content='3', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[22, 45, 43]}
Starting search from node 21
AntMessage{source=21, content='0', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[21]}
AntMessage{source=21, content='0', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[21, 6]}
AntMessage{source=21, content='0', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[21, 42]}
AntMessage{source=21, content='0', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[21, 42, 26]}
AntMessage{source=21, content='0', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[21, 42, 8]}
Starting search from node 27
AntMessage{source=27, content='31', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[27]}
AntMessage{source=27, content='31', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 0]}
AntMessage{source=27, content='31', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 48]}
AntMessage{source=27, content='31', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 26]}
AntMessage{source=27, content='31', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 18]}
Starting search from node 17
AntMessage{source=17, content='29', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[17]}
AntMessage{source=17, content='29', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[17, 14]}
AntMessage{source=17, content='29', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[17, 5]}
AntMessage{source=17, content='29', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[17, 5, 22]}
AntMessage{source=17, content='29', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[17, 5, 26]}
Starting search from node 21
AntMessage{source=21, content='48', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[21]}
AntMessage{source=21, content='48', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[21, 42]}
AntMessage{source=21, content='48', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[21, 42, 8]}
AntMessage{source=21, content='48', pheromoneLevel=1.0, ttl=1, hitCount=1, path=[21, 6]}
AntMessage{source=21, content='48', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[21, 42, 26]}
Starting search from node 27
AntMessage{source=27, content='12', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[27]}
AntMessage{source=27, content='12', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 0]}
AntMessage{source=27, content='12', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 26]}
AntMessage{source=27, content='12', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 48]}
AntMessage{source=27, content='12', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 18]}
Starting search from node 9
AntMessage{source=9, content='45', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[9]}
AntMessage{source=9, content='45', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[9, 22]}
AntMessage{source=9, content='45', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[9, 22, 45]}
AntMessage{source=9, content='45', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[9, 16]}
AntMessage{source=9, content='45', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[9, 22, 40]}
Starting search from node 12
AntMessage{source=12, content='23', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[12]}
AntMessage{source=12, content='23', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[12, 4]}
AntMessage{source=12, content='23', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[12, 38]}
AntMessage{source=12, content='23', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[12, 38, 43]}
AntMessage{source=12, content='23', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[12, 38, 16]}
Starting search from node 13
AntMessage{source=13, content='18', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[13]}
AntMessage{source=13, content='18', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[13, 49]}
AntMessage{source=13, content='18', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 49, 45]}
AntMessage{source=13, content='18', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[13, 27]}
AntMessage{source=13, content='18', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 27, 26]}
AntMessage{source=13, content='18', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 27, 0]}
AntMessage{source=13, content='18', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 49, 35]}
Starting search from node 8
AntMessage{source=8, content='26', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[8]}
Starting search from node 35
AntMessage{source=35, content='3', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[35]}
Starting search from node 28
AntMessage{source=28, content='24', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[28]}
Starting search from node 34
AntMessage{source=34, content='46', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[34]}
AntMessage{source=34, content='46', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 6]}
AntMessage{source=34, content='46', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 1]}
Starting search from node 27
AntMessage{source=27, content='16', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[27]}
AntMessage{source=27, content='16', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 26]}
AntMessage{source=27, content='16', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 0]}
AntMessage{source=27, content='16', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 18]}
AntMessage{source=27, content='16', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 48]}
Starting search from node 47
AntMessage{source=47, content='46', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[47]}
AntMessage{source=47, content='46', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 44]}
AntMessage{source=47, content='46', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 11]}
AntMessage{source=47, content='46', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 46]}
AntMessage{source=47, content='46', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 7]}
Starting search from node 8
AntMessage{source=8, content='16', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[8]}
Starting search from node 43
AntMessage{source=43, content='45', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[43]}
AntMessage{source=43, content='45', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[43, 36]}
AntMessage{source=43, content='45', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[43, 6]}
Starting search from node 10
AntMessage{source=10, content='37', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[10]}
Starting search from node 1
AntMessage{source=1, content='37', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[1]}
Starting search from node 10
AntMessage{source=10, content='11', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[10]}
Starting search from node 0
AntMessage{source=0, content='41', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[0]}
AntMessage{source=0, content='41', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[0, 48]}
AntMessage{source=0, content='41', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[0, 18]}
Starting search from node 10
AntMessage{source=10, content='9', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[10]}
Starting search from node 47
AntMessage{source=47, content='42', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[47]}
AntMessage{source=47, content='42', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 44]}
AntMessage{source=47, content='42', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 46]}
AntMessage{source=47, content='42', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 7]}
AntMessage{source=47, content='42', pheromoneLevel=1.0, ttl=1, hitCount=1, path=[47, 11]}
Starting search from node 39
AntMessage{source=39, content='5', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[39]}
Starting search from node 15
AntMessage{source=15, content='38', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[15]}
AntMessage{source=15, content='38', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[15, 39]}
AntMessage{source=15, content='38', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[15, 40]}
Starting search from node 27
AntMessage{source=27, content='18', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[27]}
AntMessage{source=27, content='18', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 26]}
AntMessage{source=27, content='18', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[27, 0]}
AntMessage{source=27, content='18', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 48]}
AntMessage{source=27, content='18', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[27, 0, 18]}
Starting search from node 12
AntMessage{source=12, content='48', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[12]}
AntMessage{source=12, content='48', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[12, 38]}
AntMessage{source=12, content='48', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[12, 38, 43]}
AntMessage{source=12, content='48', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[12, 38, 16]}
AntMessage{source=12, content='48', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[12, 4]}
Starting search from node 2
AntMessage{source=2, content='16', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[2]}
AntMessage{source=2, content='16', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[2, 48]}
AntMessage{source=2, content='16', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[2, 5]}
AntMessage{source=2, content='16', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[2, 5, 22]}
AntMessage{source=2, content='16', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[2, 5, 26]}
Starting search from node 42
AntMessage{source=42, content='38', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[42]}
AntMessage{source=42, content='38', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[42, 26]}
AntMessage{source=42, content='38', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[42, 8]}
Starting search from node 7
AntMessage{source=7, content='14', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[7]}
AntMessage{source=7, content='14', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[7, 4]}
AntMessage{source=7, content='14', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[7, 28]}
Starting search from node 24
AntMessage{source=24, content='3', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[24]}
AntMessage{source=24, content='3', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[24, 30]}
AntMessage{source=24, content='3', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[24, 30, 21]}
AntMessage{source=24, content='3', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[24, 30, 25]}
AntMessage{source=24, content='3', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[24, 10]}
Starting search from node 32
AntMessage{source=32, content='46', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[32]}
AntMessage{source=32, content='46', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[32, 2]}
AntMessage{source=32, content='46', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[32, 36]}
AntMessage{source=32, content='46', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[32, 2, 5]}
AntMessage{source=32, content='46', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[32, 2, 48]}
Starting search from node 16
AntMessage{source=16, content='22', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[16]}
Starting search from node 34
AntMessage{source=34, content='41', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[34]}
AntMessage{source=34, content='41', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 6]}
AntMessage{source=34, content='41', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 1]}
Starting search from node 46
AntMessage{source=46, content='34', pheromoneLevel=1.0, ttl=2, hitCount=1, path=[46]}
Starting search from node 29
AntMessage{source=29, content='28', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[29]}
AntMessage{source=29, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[29, 32]}
AntMessage{source=29, content='28', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[29, 32, 36]}
AntMessage{source=29, content='28', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[29, 32, 2]}
AntMessage{source=29, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[29, 8]}
Starting search from node 44
AntMessage{source=44, content='38', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[44]}
AntMessage{source=44, content='38', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[44, 46]}
AntMessage{source=44, content='38', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[44, 7]}
AntMessage{source=44, content='38', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[44, 7, 28]}
AntMessage{source=44, content='38', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[44, 7, 4]}
Starting search from node 1
AntMessage{source=1, content='16', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[1]}
Starting search from node 42
AntMessage{source=42, content='28', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[42]}
AntMessage{source=42, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[42, 26]}
AntMessage{source=42, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[42, 8]}
Starting search from node 46
AntMessage{source=46, content='28', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[46]}
Starting search from node 41
AntMessage{source=41, content='44', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[41]}
AntMessage{source=41, content='44', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[41, 48]}
AntMessage{source=41, content='44', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[41, 0]}
AntMessage{source=41, content='44', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[41, 0, 18]}
AntMessage{source=41, content='44', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[41, 0, 48]}
Starting search from node 47
AntMessage{source=47, content='7', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[47]}
AntMessage{source=47, content='7', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 44]}
AntMessage{source=47, content='7', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 7]}
AntMessage{source=47, content='7', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 46]}
AntMessage{source=47, content='7', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 11]}
Starting search from node 47
AntMessage{source=47, content='23', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[47]}
AntMessage{source=47, content='23', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 11]}
AntMessage{source=47, content='23', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 44]}
AntMessage{source=47, content='23', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 7]}
AntMessage{source=47, content='23', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 46]}
Starting search from node 31
AntMessage{source=31, content='26', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[31]}
Starting search from node 39
AntMessage{source=39, content='19', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[39]}
Starting search from node 40
AntMessage{source=40, content='19', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[40]}
Starting search from node 26
AntMessage{source=26, content='4', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[26]}
Starting search from node 32
AntMessage{source=32, content='28', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[32]}
AntMessage{source=32, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[32, 2]}
AntMessage{source=32, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[32, 36]}
AntMessage{source=32, content='28', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[32, 2, 48]}
AntMessage{source=32, content='28', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[32, 2, 5]}
Starting search from node 15
AntMessage{source=15, content='9', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[15]}
AntMessage{source=15, content='9', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[15, 40]}
AntMessage{source=15, content='9', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[15, 39]}
Starting search from node 14
AntMessage{source=14, content='20', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[14]}
Starting search from node 10
AntMessage{source=10, content='16', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[10]}
Starting search from node 13
AntMessage{source=13, content='16', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[13]}
AntMessage{source=13, content='16', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[13, 49]}
AntMessage{source=13, content='16', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 49, 45]}
AntMessage{source=13, content='16', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[13, 27]}
AntMessage{source=13, content='16', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 27, 26]}
AntMessage{source=13, content='16', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 27, 0]}
AntMessage{source=13, content='16', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[13, 49, 35]}
Starting search from node 16
AntMessage{source=16, content='21', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[16]}
Starting search from node 28
AntMessage{source=28, content='14', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[28]}
Starting search from node 16
AntMessage{source=16, content='20', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[16]}
Starting search from node 8
AntMessage{source=8, content='36', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[8]}
Starting search from node 34
AntMessage{source=34, content='37', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[34]}
AntMessage{source=34, content='37', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 1]}
AntMessage{source=34, content='37', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[34, 6]}
Starting search from node 31
AntMessage{source=31, content='2', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[31]}
Starting search from node 47
AntMessage{source=47, content='39', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[47]}
AntMessage{source=47, content='39', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 44]}
AntMessage{source=47, content='39', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 46]}
AntMessage{source=47, content='39', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 7]}
AntMessage{source=47, content='39', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 11]}
Starting search from node 3
AntMessage{source=3, content='1', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[3]}
AntMessage{source=3, content='1', pheromoneLevel=1.0, ttl=1, hitCount=1, path=[3, 12]}
AntMessage{source=3, content='1', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[3, 44]}
AntMessage{source=3, content='1', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[3, 44, 7]}
AntMessage{source=3, content='1', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[3, 44, 46]}
Starting search from node 42
AntMessage{source=42, content='28', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[42]}
AntMessage{source=42, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[42, 26]}
AntMessage{source=42, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[42, 8]}
Starting search from node 17
AntMessage{source=17, content='36', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[17]}
AntMessage{source=17, content='36', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[17, 14]}
AntMessage{source=17, content='36', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[17, 5]}
AntMessage{source=17, content='36', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[17, 5, 22]}
AntMessage{source=17, content='36', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[17, 5, 26]}
Starting search from node 14
AntMessage{source=14, content='0', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[14]}
Starting search from node 31
AntMessage{source=31, content='10', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[31]}
Starting search from node 43
AntMessage{source=43, content='18', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[43]}
AntMessage{source=43, content='18', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[43, 6]}
AntMessage{source=43, content='18', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[43, 36]}
Starting search from node 8
AntMessage{source=8, content='0', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[8]}
Starting search from node 24
AntMessage{source=24, content='46', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[24]}
AntMessage{source=24, content='46', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[24, 10]}
AntMessage{source=24, content='46', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[24, 30]}
AntMessage{source=24, content='46', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[24, 30, 25]}
AntMessage{source=24, content='46', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[24, 30, 21]}
Starting search from node 7
AntMessage{source=7, content='44', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[7]}
AntMessage{source=7, content='44', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[7, 28]}
AntMessage{source=7, content='44', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[7, 4]}
Starting search from node 37
AntMessage{source=37, content='28', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[37]}
AntMessage{source=37, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[37, 4]}
AntMessage{source=37, content='28', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[37, 33]}
AntMessage{source=37, content='28', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[37, 33, 42]}
AntMessage{source=37, content='28', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[37, 33, 29]}
Starting search from node 5
AntMessage{source=5, content='45', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[5]}
AntMessage{source=5, content='45', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[5, 26]}
AntMessage{source=5, content='45', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[5, 22]}
AntMessage{source=5, content='45', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[5, 22, 45]}
AntMessage{source=5, content='45', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[5, 22, 40]}
Starting search from node 18
AntMessage{source=18, content='44', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[18]}
Starting search from node 38
AntMessage{source=38, content='19', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[38]}
AntMessage{source=38, content='19', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[38, 43]}
AntMessage{source=38, content='19', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[38, 43, 36]}
AntMessage{source=38, content='19', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[38, 43, 6]}
AntMessage{source=38, content='19', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[38, 16]}
Starting search from node 21
AntMessage{source=21, content='24', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[21]}
AntMessage{source=21, content='24', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[21, 6]}
AntMessage{source=21, content='24', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[21, 42]}
AntMessage{source=21, content='24', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[21, 42, 26]}
AntMessage{source=21, content='24', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[21, 42, 8]}
Starting search from node 11
AntMessage{source=11, content='40', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[11]}
Starting search from node 47
AntMessage{source=47, content='48', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[47]}
AntMessage{source=47, content='48', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 44]}
AntMessage{source=47, content='48', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 46]}
AntMessage{source=47, content='48', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[47, 44, 7]}
AntMessage{source=47, content='48', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[47, 11]}
Starting search from node 44
AntMessage{source=44, content='15', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[44]}
AntMessage{source=44, content='15', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[44, 46]}
AntMessage{source=44, content='15', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[44, 7]}
AntMessage{source=44, content='15', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[44, 7, 28]}
AntMessage{source=44, content='15', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[44, 7, 4]}
Starting search from node 22
AntMessage{source=22, content='0', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[22]}
AntMessage{source=22, content='0', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[22, 40]}
AntMessage{source=22, content='0', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[22, 45]}
AntMessage{source=22, content='0', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[22, 45, 43]}
AntMessage{source=22, content='0', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[22, 45, 27]}
Starting search from node 7
AntMessage{source=7, content='37', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[7]}
AntMessage{source=7, content='37', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[7, 28]}
AntMessage{source=7, content='37', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[7, 4]}
Starting search from node 25
AntMessage{source=25, content='30', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[25]}
AntMessage{source=25, content='30', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[25, 16]}
AntMessage{source=25, content='30', pheromoneLevel=1.0, ttl=1, hitCount=0, path=[25, 37]}
AntMessage{source=25, content='30', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[25, 37, 33]}
AntMessage{source=25, content='30', pheromoneLevel=1.0, ttl=0, hitCount=0, path=[25, 37, 4]}
Starting search from node 11
AntMessage{source=11, content='1', pheromoneLevel=1.0, ttl=2, hitCount=0, path=[11]}
EDSimulator: queue is empty, quitting at time 499
"""
# Parse the updated log output to get paths
paths = parse_log_output(log_output)

# Create a directed graph
G = nx.DiGraph()

# Add directed edges based on paths
for path in paths:
    for i in range(len(path) - 1):
        G.add_edge(path[i], path[i+1])

# Choose a layout for our graph
pos = nx.spring_layout(G, k=0.15, iterations=20)  # k: Optimal distance between nodes. Increase to spread out nodes

# Create figure with specified size and layout management
plt.figure(figsize=(15, 10), constrained_layout=True)

# Draw the directed network with arrows
nx.draw(G, pos, with_labels=True, node_size=500, node_color='skyblue', font_size=10, font_weight='bold',
        edge_color='gray', width=0.5, alpha=0.7, arrows=True, arrowsize=10, arrowstyle='-|>')

# Save the plot to a file
plt.savefig("network_graph.png", format="PNG")

# Show the plot
plt.show()
# Out:
# /var/folders/dy/733gh7p95s1bdf9dhqfdl2ch0000gn/T/ipykernel_10188/1492885447.py:619: UserWarning: There are no gridspecs with layoutgrids. Possibly did not call parent GridSpec with the "figure" keyword
#   plt.savefig("network_graph.png", format="PNG")
